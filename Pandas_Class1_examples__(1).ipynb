# %% [markdown]
# <a href="https://colab.research.google.com/github/Breddy10/Python-basics/blob/main/Pandas_Class1_examples__(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
5+5
# Out:
# 10

# %%
import pandas as pd

# %%
df=pd.read_csv('Salaries.csv')

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df.tail()
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
df.tail(10)
# Out:
#          rank discipline  phd  service     sex  salary
# 68   AsstProf          A    4        2  Female   77500
# 69       Prof          A   28        7  Female  116450
# 70   AsstProf          A    8        3  Female   78500
# 71  AssocProf          B   12        9  Female   71065
# 72       Prof          B   24       15  Female  161101
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
df.shape
# Out:
# (78, 6)

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
#to see what data types are there
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
#information of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        78 non-null     object
#  1   discipline  78 non-null     object
#  2   phd         78 non-null     int64
#  3   service     78 non-null     int64
#  4   sex         78 non-null     object
#  5   salary      78 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 3.8+ KB

# %%
#to see if there are any null values
df.isnull()
# Out:
#      rank  discipline    phd  service    sex  salary
# 0   False       False  False    False  False   False
# 1   False       False  False    False  False   False
# 2   False       False  False    False  False   False
# 3   False       False  False    False  False   False
# 4   False       False  False    False  False   False
# ..    ...         ...    ...      ...    ...     ...
# 73  False       False  False    False  False   False
# 74  False       False  False    False  False   False
# 75  False       False  False    False  False   False
# 76  False       False  False    False  False   False
# 77  False       False  False    False  False   False
#
# [78 rows x 6 columns]

# %%
#to get the whole observations to see
pd.set_option('display.max_rows',None)

# %%
df.isnull()
# Out:
#      rank  discipline    phd  service    sex  salary
# 0   False       False  False    False  False   False
# 1   False       False  False    False  False   False
# 2   False       False  False    False  False   False
# 3   False       False  False    False  False   False
# 4   False       False  False    False  False   False
# 5   False       False  False    False  False   False
# 6   False       False  False    False  False   False
# 7   False       False  False    False  False   False
# 8   False       False  False    False  False   False
# 9   False       False  False    False  False   False
# 10  False       False  False    False  False   False
# 11  False       False  False    False  False   False
# 12  False       False  False    False  False   False
# 13  False       False  False    False  False   False
# 14  False       False  False    False  False   False
# 15  False       False  False    False  False   False
# 16  False       False  False    False  False   False
# ...

# %%
#to see null values
df.isnull().sum()
# Out:
# rank          0
# discipline    0
# phd           0
# service       0
# sex           0
# salary        0
# dtype: int64

# %%
#displays all the numerical info of the data
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
#tells values of the salary
df['salary']
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
# 5     122400
# 6      81285
# 7     126300
# 8      94350
# 9      57800
# 10    128250
# 11    134778
# 12     88000
# 13    162200
# 14    153750
# 15    150480
# 16     75044
# 17     92000
# 18    107300
# 19    150500
# 20     92000
# 21    103106
# 22     73000
# 23     85000
# 24     91100
# 25     99418
# 26    148750
# 27    155865
# 28     91300
# 29    123683
# 30    107008
# 31    155750
# 32    103275
# 33    120000
# 34    119800
# 35    126933
# 36    146856
# 37    102000
# 38     91000
# 39    129000
# 40    137000
# 41     74830
# 42     80225
# 43     77000
# 44    151768
# 45    140096
# 46     74692
# 47    103613
# 48    111512
# 49    122960
# 50     97032
# 51    127512
# 52    105000
# 53     73500
# 54     62884
# 55     72500
# 56     77500
# 57     72500
# 58    144651
# 59    103994
# 60     92000
# 61    103750
# 62    109650
# 63     91000
# 64     73300
# 65    117555
# ...

# %%
#displays average of the salary
df['salary'].mean()
# Out:
# 108023.78205128205

# %%
#displays median
df['salary'].median()
# Out:
# 104671.0

# %%
#displays mode
df['salary'].mode()
# Out:
# 0    92000
# Name: salary, dtype: int64

# %%
df['salary'].var()
# Out:
# 800531254.0427907

# %%
df['salary'].std()
# Out:
# 28293.66102226417

# %%
df['salary'].min()
# Out:
# 57800

# %%
df['salary'].max()
# Out:
# 186960

# %%
df['salary'].skew()
# Out:
# 0.45210256755588096

# %%
df['salary'].kurt()
# Out:
# -0.4017126758820546

# %%
df[['salary','service']]
# Out:
#     salary  service
# 0   186960       49
# 1    93000        6
# 2   110515       20
# 3   131205       31
# 4   104800       18
# 5   122400       20
# 6    81285       17
# 7   126300       18
# 8    94350       19
# 9    57800       51
# 10  128250       33
# 11  134778       23
# 12   88000        0
# 13  162200       33
# 14  153750       19
# 15  150480        3
# 16   75044        3
# 17   92000        0
# 18  107300        7
# 19  150500       27
# 20   92000        4
# 21  103106       30
# 22   73000        2
# 23   85000        0
# 24   91100       23
# 25   99418       31
# 26  148750       19
# 27  155865       43
# 28   91300        2
# 29  123683       20
# 30  107008        7
# 31  155750       21
# 32  103275       19
# 33  120000       18
# 34  119800        8
# 35  126933       23
# 36  146856       45
# 37  102000        8
# 38   91000        3
# 39  129000       18
# 40  137000       36
# 41   74830        8
# 42   80225        2
# 43   77000        0
# ...

# %%
df[['salary','service']].mean()
# Out:
# salary     108023.782051
# service        15.051282
# dtype: float64

# %%
df.mean()
# Out:
# <ipython-input-32-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# phd            19.705128
# service        15.051282
# salary     108023.782051
# dtype: float64

# %%
#for not showing warnings
import warnings
warnings.filterwarnings('ignore')
df.mean()
# Out:
# phd            19.705128
# service        15.051282
# salary     108023.782051
# dtype: float64

# %%
df['salary']>120000
# Out:
# 0      True
# 1     False
# 2     False
# 3      True
# 4     False
# 5      True
# 6     False
# 7      True
# 8     False
# 9     False
# 10     True
# 11     True
# 12    False
# 13     True
# 14     True
# 15     True
# 16    False
# 17    False
# 18    False
# 19     True
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26     True
# 27     True
# 28    False
# 29     True
# 30    False
# 31     True
# 32    False
# 33    False
# 34    False
# 35     True
# 36     True
# 37    False
# 38    False
# 39     True
# 40     True
# 41    False
# 42    False
# 43    False
# 44     True
# 45     True
# 46    False
# 47    False
# 48    False
# 49     True
# 50    False
# 51     True
# 52    False
# 53    False
# 54    False
# 55    False
# 56    False
# 57    False
# 58     True
# 59    False
# 60    False
# 61    False
# 62    False
# 63    False
# 64    False
# 65    False
# 66    False
# 67    False
# 68    False
# 69    False
# 70    False
# ...

# %%
#displays all the records of salary >120000
df[df['salary']>120000]
# Out:
#     rank discipline  phd  service     sex  salary
# 0   Prof          B   56       49    Male  186960
# 3   Prof          A   40       31    Male  131205
# 5   Prof          A   20       20    Male  122400
# 7   Prof          A   18       18    Male  126300
# 10  Prof          B   39       33    Male  128250
# 11  Prof          B   23       23    Male  134778
# 13  Prof          B   35       33    Male  162200
# 14  Prof          B   25       19    Male  153750
# 15  Prof          B   17        3    Male  150480
# 19  Prof          A   29       27    Male  150500
# 26  Prof          A   38       19    Male  148750
# 27  Prof          A   45       43    Male  155865
# 29  Prof          B   21       20    Male  123683
# 31  Prof          B   22       21    Male  155750
# 35  Prof          B   28       23    Male  126933
# 36  Prof          B   45       45    Male  146856
# 39  Prof          B   18       18  Female  129000
# 40  Prof          A   39       36  Female  137000
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.max()
# Out:
# rank            Prof
# discipline         B
# phd               56
# service           51
# sex             Male
# salary        186960
# dtype: object

# %%
df['rank'].value_counts()
# Out:
# Prof         46
# AsstProf     19
# AssocProf    13
# Name: rank, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.read_csv('Universities.csv')

# %%
df1
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
plt.figure(figsize=(4,4))
plt.hist(df1['Accept'])
plt.xlabel('Accept')
plt.ylabel('count')
plt.title('Histogram of Accept')
#for not displaying values
plt.show()

# %%
plt.figure(figsize=(4,4))
plt.hist(df1['SAT'])
plt.xlabel('SAT')
plt.ylabel('Count')
plt.title('Histogram of SAT')
#for not displaying values
plt.show()

# %%
sns.histplot(df1['Accept'])
# Out:
# <Axes: xlabel='Accept', ylabel='Count'>

# %%
sns.histplot(df1['SAT'])
# Out:
# <Axes: xlabel='SAT', ylabel='Count'>

# %%
sns.distplot(df1['Accept'])
# Out:
# <Axes: xlabel='Accept', ylabel='Density'>

# %%
import warnings
warnings.filterwarnings('ignore')
sns.displot(df1['Accept'])

# %%
plt.plot(df1['Accept'],df1['Expenses'],'r+')
plt.xlabel('Accept')
plt.ylabel('Expenses')
plt.title('Scatterplot of Accept vs Expenses')
# Out:
# Text(0.5, 1.0, 'Scatterplot of Accept vs Expenses')

# %%
#want to know any of the function
help(plt.plot)
help(plt.hist)
# Out:
# Help on function plot in module matplotlib.pyplot:
#
# plot(*args, scalex=True, scaley=True, data=None, **kwargs)
#     Plot y versus x as lines and/or markers.
#
#     Call signatures::
#
#         plot([x], y, [fmt], *, data=None, **kwargs)
#         plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
#     The coordinates of the points or line nodes are given by *x*, *y*.
#
#     The optional parameter *fmt* is a convenient way for defining basic
#     formatting like color, marker and linestyle. It's a shortcut string
#     notation described in the *Notes* section below.
#
#     >>> plot(x, y)        # plot x and y using default line style and color
#     >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
#     >>> plot(y)           # plot y using x as index array 0..N-1
#     >>> plot(y, 'r+')     # ditto, but with red plusses
#
#     You can use `.Line2D` properties as keyword arguments for more
# ...

# %%
#to display both hiostograms and also scatterplot
sns.pairplot(df1)

# %%
df1.iloc[:,:]
#anything before colon indicated rows and anything after colon indiacted coulumns
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
df1.iloc[0:10,:]
# Out:
#            Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0         Brown  1310     89      22       13     22704        94
# 1       CalTech  1415    100      25        6     63575        81
# 2           CMU  1260     62      59        9     25026        72
# 3      Columbia  1310     76      24       12     31510        88
# 4       Cornell  1280     83      33       13     21864        90
# 5     Dartmouth  1340     89      23       10     32162        95
# 6          Duke  1315     90      30       12     31585        95
# 7    Georgetown  1255     74      24       12     20126        92
# 8       Harvard  1400     91      14       11     39525        97
# 9  JohnsHopkins  1305     75      44        7     58691        87

# %%
df1.iloc[0:10,0:3]
# Out:
#            Univ   SAT  Top10
# 0         Brown  1310     89
# 1       CalTech  1415    100
# 2           CMU  1260     62
# 3      Columbia  1310     76
# 4       Cornell  1280     83
# 5     Dartmouth  1340     89
# 6          Duke  1315     90
# 7    Georgetown  1255     74
# 8       Harvard  1400     91
# 9  JohnsHopkins  1305     75

# %%
df1.iloc[0:10,[0,2,5]]
# Out:
#            Univ  Top10  Expenses
# 0         Brown     89     22704
# 1       CalTech    100     63575
# 2           CMU     62     25026
# 3      Columbia     76     31510
# 4       Cornell     83     21864
# 5     Dartmouth     89     32162
# 6          Duke     90     31585
# 7    Georgetown     74     20126
# 8       Harvard     91     39525
# 9  JohnsHopkins     75     58691

# %%
sns.pairplot(df1.iloc[:,1:4])

# %%
plt.boxplot(df1['Accept'])
plt.show()

# %%
df1['Accept'].describe()
# Out:
# count    25.000000
# mean     39.200000
# std      19.727308
# min      14.000000
# 25%      24.000000
# 50%      36.000000
# 75%      50.000000
# max      90.000000
# Name: Accept, dtype: float64

# %%
plt.boxplot(df1['Accept'],vert=False)
plt.show()
